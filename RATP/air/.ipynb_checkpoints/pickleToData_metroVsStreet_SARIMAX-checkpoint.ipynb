# %%
# load JSON
import json
import pandas as pd

df = pd.read_pickle('franklin-d-roosevelt/airQualityDataframe-franklin-d-roosevelt-PM10.pkl')
df = df.sort_values(by=['ds'])

df1 = df

# %%
# Load the Pandas libraries with alias 'pd' 
df = pd.read_pickle('groundLevel/airQualityDataframe-ELYS.pkl')
df = df.sort_values(by=['ds'])

df2 = df
test = df2.y
test = test.astype(float)
df2.y = test

# %%
# merge two dataframes matching
df_merge = df1.merge(df2, left_on='ds', right_on='ds', how='inner')
df_merge_org = df_merge
df_merge = df_merge[0:500] # extract a small part

plt.plot(df_merge['ds'],df_merge['y_x'])
plt.plot(df_merge['ds'],df_merge['y_y'])
plt.autoscale(enable=True, axis='x', tight=True)

# %%
import matplotlib.pyplot as plt
import matplotlib

font = {'size': 16,             # font setting
       'weight':'normal'}       # font setting
matplotlib.rc('font', **font)   # font setting

plt.figure(figsize=(6, 6))
plt.scatter(df_merge['y_x'],df_merge['y_y'],5)
plt.xlabel('PM10,metro')
plt.ylabel('PM10,street')
# Out:
# Text(0, 0.5, 'PM10,street')

# %%
# Determine differencing (d) Augmented Dickey Fuller test
from statsmodels.tsa.stattools import adfuller
from numpy import log
result = adfuller(df_merge.y_x.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1]) # p < 0.05 --> stationary, no differencing (d=0)
# Out:
# ADF Statistic: -7.025571
# p-value: 0.000000

# %%
# Determine P (AR)
# PACF plot of 1st differenced series (partial autocorrelation)
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df_merge.y_x.diff()); axes[0].set_title('1st Differencing')
axes[1].set(xlim=(0,100))
plot_pacf(df_merge.y_x.diff().dropna(), ax=axes[1])

plt.show() # crossed the threshold at 0 --> set to 0

# %%
# Determine Q
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df_merge.y_x.diff()); axes[0].set_title('1st Differencing')
#axes[1].set(ylim=(0,1.2))
plot_acf(df_merge.y_x.diff().dropna(), ax=axes[1])

plt.show()

# %%
# SARIMAX
import pmdarima as pm

df_merge = df_merge.dropna() # drop nan's (any rows with at least 1 NaN)

# SARIMAX Model
sxmodel = pm.auto_arima(df_merge[['y_x']], exogenous=df_merge[['y_y']],
                           start_p=0, start_q=0,
                           test='adf',
                           max_p=3, max_q=3, m=24,
                           start_P=0, seasonal=True,
                           d=None, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 1, 24); AIC=3793.582, BIC=3810.027, Fit time=4.100 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 24); AIC=3897.092, BIC=3909.426, Fit time=0.241 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 24); AIC=3589.332, BIC=3609.890, Fit time=4.944 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 24); AIC=3571.371, BIC=3591.929, Fit time=9.891 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 1, 1, 24); AIC=3564.188, BIC=3588.857, Fit time=19.656 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 1, 0, 24); AIC=3645.155, BIC=3665.713, Fit time=5.933 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 1, 2, 24); AIC=3573.181, BIC=3601.961, Fit time=20.810 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 0, 24); AIC=3746.795, BIC=3763.241, Fit time=0.842 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 1, 2, 24); AIC=3563.767, BIC=3596.659, Fit time=55.109 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 1, 2, 24); AIC=3485.167, BIC=3522.170, Fit time=51.335 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 2, 24); AIC=3487.737, BIC=3520.629, Fit time=45.625 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(2, 1, 2, 24); AIC=3485.858, BIC=3526.972, Fit time=62.182 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 1, 2, 24); AIC=3763.701, BIC=3792.481, Fit time=36.954 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 1, 2, 24); AIC=3485.340, BIC=3530.566, Fit time=72.602 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 24); AIC=3483.353, BIC=3516.245, Fit time=52.904 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 24); AIC=3481.771, BIC=3510.551, Fit time=17.708 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 24); AIC=3702.676, BIC=3723.233, Fit time=1.678 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 1, 24); AIC=3481.337, BIC=3514.229, Fit time=15.297 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 1, 24); AIC=3481.050, BIC=3509.831, Fit time=15.328 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 1, 24); AIC=3481.951, BIC=3518.954, Fit time=23.775 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 24); AIC=3479.451, BIC=3504.120, Fit time=13.439 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 0, 24); AIC=3702.632, BIC=3723.189, Fit time=1.315 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 2, 24); AIC=3481.093, BIC=3509.873, Fit time=31.111 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 2, 24); AIC=3482.620, BIC=3515.512, Fit time=45.894 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 1, 24); AIC=3484.046, BIC=3504.604, Fit time=9.590 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 1, 1, 24); AIC=3480.539, BIC=3509.319, Fit time=14.818 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 1, 24); AIC=3479.482, BIC=3508.262, Fit time=17.812 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 1, 1, 24); AIC=3480.093, BIC=3512.985, Fit time=18.667 seconds
# Total fit time: 669.571 seconds

# %%
# ARIMAX model summary
sxmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  475
# Model:             SARIMAX(2, 0, 0)x(0, 1, 1, 24)   Log Likelihood               -1733.725
# Date:                            Tue, 24 Sep 2019   AIC                           3479.451
# Time:                                    14:18:54   BIC                           3504.120
# Sample:                                         0   HQIC                          3489.173
#                                             - 475
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0562      0.098      0.572      0.567      -0.136       0.249
# x1             0.0602      0.072      0.834      0.404      -0.081       0.202
# ar.L1          0.8027      0.035     22.620      0.000       0.733       0.872
# ar.L2         -0.1226      0.038     -3.197      0.001      -0.198      -0.047
# ma.S.L24      -0.9997     11.033     -0.091      0.928     -22.624      20.624
# sigma2       108.8869   1199.314      0.091      0.928   -2241.726    2459.500
# ===================================================================================
# Ljung-Box (Q):                       79.37   Jarque-Bera (JB):                40.62
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.19
# Prob(H) (two-sided):                  0.28   Kurtosis:                         4.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Forecast
import numpy as np
n_periods = 96
df_merge_fcst = df_merge_org[201:297]

# %%
fitted, confint = sxmodel.predict(n_periods=n_periods, 
                                  exogenous=df_merge_fcst[['y_y']],
                                  return_conf_int=True)

index_of_fc = pd.date_range(df_merge.iloc[-1].ds, periods = n_periods, freq='H')
#print(confint)

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
#print(fitted_series)
plt.figure(figsize=(10,1))
plt.plot(df_merge['ds'],df_merge['y_x'])
#df_merge_fcst['fitted'] = fitted_series
#plt.figure(figsize=(10,1))
plt.plot(fitted_series, color='darkgreen')#,marker="o")
#plt.fill_between(lower_series.index, 
#                 lower_series, 
#                 upper_series, 
#                 color='k', alpha=.15)

#plt.title("SARIMAX Forecast of a10 - Drug Sales")
#plt.show()
