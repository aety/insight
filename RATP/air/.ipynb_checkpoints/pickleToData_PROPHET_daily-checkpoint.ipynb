# %%
# load JSON
import json
import pandas as pd
 
# hourly data 
data = pd.read_pickle('franklin-d-roosevelt/airQualityDataframe-franklin-d-roosevelt-PM10.pkl')
data = data.sort_values(by=['ds'])
data['just_date'] = data['ds'].dt.date
df_h = data

# group by date
data_d = data.groupby(['just_date'],squeeze=True).mean()
data_d.columns = ['_'.join(col).strip() for col in data_d.columns.values]
data_d = data_d.reset_index()
data_d.columns = ['ds','y'] # rename column
df_d = data_d

import matplotlib.pyplot as plt
plt.figure(figsize=(15,3))
plt.plot(df_d['ds'],df_d['y'])
plt.title('by date')
#plt.xlim('2016-06-30','2017-03-03')
plt.figure(figsize=(15,3))
plt.plot(df_h['ds'],df_h['y'])
plt.title('by hour')
# Out:
# Text(0.5, 1.0, 'by hour')

# %%
df = df_d # select daily or hourly daya

from fbprophet import Prophet

m = Prophet(changepoint_prior_scale=1) #  Increasing scale will make the trend more flexible:
m.fit(df)
future = m.make_future_dataframe(periods=180, freq='D')
forecast = m.predict(future)
pd.plotting.register_matplotlib_converters() # this resolves some issues with data type
fig = m.plot(forecast)
components_fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# PROPHET validation
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(m, horizon ='180 days') # horizon: forecast ; initial: training (default: 3x horizon); 
df_cv.head()
# Out:
# INFO:fbprophet:Making 20 forecasts with cutoffs between 2014-07-20 00:00:00 and 2019-03-26 00:00:00
#           ds       yhat  yhat_lower  yhat_upper          y     cutoff
# 0 2014-07-21  49.753554   34.853140   66.075151  43.208333 2014-07-20
# 1 2014-07-22  51.113104   34.637246   67.857447  39.958333 2014-07-20
# 2 2014-07-23  54.636529   37.832067   71.587270  47.250000 2014-07-20
# 3 2014-07-24  55.542191   39.077958   70.243460  47.666667 2014-07-20
# 4 2014-07-25  50.822928   33.276630   66.551836  39.791667 2014-07-20

# %%
# Performance metrics
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()

# mean squared error (MSE), root mean squared error (RMSE), mean absolute error (MAE), mean absolute percent error (MAPE)
# computed on a rolling window of the predictions in df_cv after sorting by horizon (ds minus cutoff).
# By default, 10% of the predictions in each window (can be changed) 
# high rollingwindow --> smoother average curve 

# Visualize cross-validation
from fbprophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape')

# %%
# Percentage errors
mape = 100*sum(abs( (df_cv.yhat - df_cv.y) / df_cv.y) ) / len(df_cv) # MAPE
smape = 100*sum( abs(df_cv.yhat - df_cv.y) / (abs(df_cv.yhat) + abs(df_cv.y)) ) /len(df_cv) / 2 # SMAPE
print('MAPE = ' + str(mape) + '%')
print('SMAPE = ' + str(smape) + '%')
# Out:
# MAPE = 59.09771598083595%
# SMAPE = 13.490311061721949%

# %%
import pickle
pkl_path = "franklin-d-roosevelt/PM10_daily_m.pkl"
with open(pkl_path, "wb") as f:
    # Pickle the 'Prophet' model using the highest protocol available.
    pickle.dump(m, f)

# save the dataframe
forecast.to_pickle("franklin-d-roosevelt/PM10_daily_forecast.pkl")
print("*** Data Saved ***")
# Out:
# *** Data Saved ***
