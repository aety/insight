# %%
import numpy as np
test = np.array([[5000,  16.13646602812886],
        [10000, 15.13057036820503],
        [15000, 17.72657811508373],
        [20000, 36.62962013304121],
        [25000, 29.003435928351603],
        [30000, 21.26478744416783],
        [35000, 30.148436561689696],
        [40000, 31.061258629527774],
        [45000, 23.74076241645964],
        [50000, 17.678008279889458]])
print(test)
# Out:
# [[5.00000000e+03 1.61364660e+01]
#  [1.00000000e+04 1.51305704e+01]
#  [1.50000000e+04 1.77265781e+01]
#  [2.00000000e+04 3.66296201e+01]
#  [2.50000000e+04 2.90034359e+01]
#  [3.00000000e+04 2.12647874e+01]
#  [3.50000000e+04 3.01484366e+01]
#  [4.00000000e+04 3.10612586e+01]
#  [4.50000000e+04 2.37407624e+01]
#  [5.00000000e+04 1.76780083e+01]]

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('dark_background')
font = {'size': 16,             # font setting
       'weight':'normal'}       # font setting
matplotlib.rc('font', **font)   # font setting

plt.plot(test[:,0],test[:,1],'w')
plt.scatter(test[1,0],test[1,1],100,'w')
plt.xlabel('samples')
plt.ylabel('error %')
plt.savefig('optimizeSampleSize.png',transparent=True)
