# %%
# this script queries data from RATP 
# limitation: only the most recent 10k entries available
import requests
response = requests.get('https://data.ratp.fr/api/records/1.0/search/?dataset=qualite-de-lair-mesuree-dans-la-station-chatelet&rows=10&facet=dateheure')

# %%
print(response.json())
# Out:
# {'nhits': 59055, 'parameters': {'dataset': 'qualite-de-lair-mesuree-dans-la-station-chatelet', 'timezone': 'UTC', 'rows': 10, 'format': 'json', 'facet': ['dateheure']}, 'records': [{'datasetid': 'qualite-de-lair-mesuree-dans-la-station-chatelet', 'recordid': 'e5c0971e6853150c5a4349c848ab1e2dd48616b8', 'fields': {'c2cha4': 673, 'tcha4': 25.5, 'dateheure': '2014-11-02T16:00:00+00:00', 'hycha4': 46.5, '10cha4': 156, 'n2cha4': 39}, 'record_timestamp': '2017-12-11T13:32:33.963000+00:00'}, {'datasetid': 'qualite-de-lair-mesuree-dans-la-station-chatelet', 'recordid': '4ed18cb38bbe8df441567184cd7659e161f622c9', 'fields': {'c2cha4': 792, 'tcha4': 25.8, 'dateheure': '2016-06-09T17:00:00+00:00', 'hycha4': 46.0, '10cha4': 239, 'n2cha4': 38, 'nocha4': 15}, 'record_timestamp': '2018-06-27T08:50:39.639000+00:00'}, {'datasetid': 'qualite-de-lair-mesuree-dans-la-station-chatelet', 'recordid': 'fb0d56c811815ecd5b735cbe3da21f0f7c4ba237', 'fields': {'c2cha4': 755, 'tcha4': 25.1, 'dateheure': '2014-11-03
# ...
