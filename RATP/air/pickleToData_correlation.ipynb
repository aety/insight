# %%
# load JSON
import json
import pandas as pd
import matplotlib.pyplot as plt

dataArr = []

dispArr = ['CO2','temp','humidity','NO2','NO']
for d in dispArr:
    counter = counter + 1
    data1 = pd.read_pickle('franklin-d-roosevelt/airQualityDataframe-franklin-d-roosevelt-' + 'PM10' + '.pkl')
    data2 = pd.read_pickle('franklin-d-roosevelt/airQualityDataframe-franklin-d-roosevelt-' + d + '.pkl')
    plt.figure()
    plt.scatter(data1['y'],data2['y'],2)
    plt.xlabel('PM10')
    plt.ylabel(d)
