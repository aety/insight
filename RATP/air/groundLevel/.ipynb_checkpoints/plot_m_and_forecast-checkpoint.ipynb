# %%
import pandas as pd
forecast = pd.read_pickle('ground_PM10_hourly_forecast.pkl')
m = pd.read_pickle('ground_PM10_hourly_m.pkl')
pd.plotting.register_matplotlib_converters() # this resolves some issues with data type

# %%
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.pyplot as plt
##pd.plotting.register_matplotlib_converters() # this resolves some issues with data type
plt.style.use('dark_background')
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot()
 
font = {'size': 16,             # font setting
       'weight':'normal'}       # font setting
matplotlib.rc('font', **font)   # font setting

fcst = forecast
fcst_t = fcst['ds'].dt.to_pydatetime()
plt.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], '.',color='#009999')
plt.plot(fcst_t, fcst['yhat'],'-', c='w')
xlabel = 'time'
ylabel = 'PM10'
plt.xlabel(xlabel)
plt.ylabel(ylabel)
# Out:
# Text(0, 0.5, 'PM10')
