# %% [raw]
# Need to install the following client library (https://newsapi.org/docs/client-libraries/python)
# pip install newsapi-python

# %%
# I want to show my users live top and breaking news headlines
# Let's make a request to get live top headlines in the US right now. We'll use the /top-headlines endpoint for this.

import requests
url = ('https://newsapi.org/v2/top-headlines?'
       'country=fr&'
       'apiKey=79a135e137a24381804e7d72de05bb2d')
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 34, 'articles': [{'source': {'id': None, 'name': 'Ohmymag.com'}, 'author': 'Marion Mancho', 'title': 'PMA pour toutes : le projet pour une reconnaissance des mères lesbiennes ? - Ohmymag', 'description': "Mères “sans distinction et sans hiérarchie”, les mots de la ministre de la Justice résonnent encore dans l’hémicycle de l'Assemblée Nationale. La loi sur la bioéthique est au …", 'url': 'https://www.ohmymag.com/bioethique/pma-pour-toutes-le-projet-pour-une-reconnaissance-des-meres-lesbiennes_art130315.html', 'urlToImage': 'https://img.ohmymag.com/s3/fromm/1280/bioethique/default_2019-09-10_586230fa-dd77-41c2-9b13-bae8703301c5.jpeg', 'publishedAt': '2019-09-10T12:04:10Z', 'content': "Mères sans distinction et sans hiérarchie, les mots de la ministre de la Justice résonnent encore dans lhémicycle de l'Assemblée Nationale. La loi sur la bioéthique est au coeur des débats et louverture de la filiation des mères lesbiennes relève dune totale … [+2486 char
# ...

# %%
# If you want headlines just from a specific source, for example BBC News
import requests
url = ('https://newsapi.org/v2/top-headlines?'
       'sources=bbc-news&'
       'apiKey=79a135e137a24381804e7d72de05bb2d')
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 10, 'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "Russia plays down story of 'extracted US spy'", 'description': 'The Kremlin says an alleged US agent was not a high-level official and had been fired years earlier.', 'url': 'http://www.bbc.co.uk/news/world-us-canada-49651576', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/16FB/production/_108738850_039402390-1.jpg', 'publishedAt': '2019-09-10T14:13:48Z', 'content': "Image copyrightEPAImage caption\r\n CNN said President Trump's meeting with Russia's Sergei Lavrov in 2017 had spooked the CIA\r\nMoscow has played down reports in American media that the US extracted a high-level spy from Russia in 2017 fearing his cover could b… [+4326 chars]"}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "The day the dinosaurs' world fell apart", 'description': 'Scientists reconstruct the seconds, minutes and hours f
# ...

# %%
# I want to search for news articles that mention a specific topic or keyword (6 months)
import requests

url = ('https://newsapi.org/v2/everything?'
       'q=instant-pot&'
       'from=2019-09-10&'
       'sortBy=popularity&'
       'apiKey=79a135e137a24381804e7d72de05bb2d')

response = requests.get(url)

print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 51, 'articles': [{'source': {'id': 'mashable', 'name': 'Mashable'}, 'author': 'Leah Stodart', 'title': "The Instant Pot Max is $50 off — the first time we've ever seen it on sale", 'description': 'TL;DR: The extremely versatile Instant Pot Max (6-quart) is on sale for $149.95, saving you $49.96. Food is a very subjective thing. When a group of friends is trying to decide on the cuisine of the night, the suggestion "something good" means something diffe…', 'url': 'https://mashable.com/shopping/deal-sept-10-instant-pot-max/', 'urlToImage': 'https://mondrian.mashable.com/2019%252F09%252F10%252F1d%252F7671979cbe834d6dbfabaa79570b79f4.19fba.jpg%252F1200x630.jpg?signature=C77idernjAPD_qymN9OFyek9PqI=', 'publishedAt': '2019-09-10T14:56:00Z', 'content': 'TL;DR: The extremely versatile Instant Pot Max (6-quart) is on sale for $149.95, saving you $49.96.\r\nFood is a very subjective thing.\r\nWhen a group of friends is trying to decide on the cuisine of the nig
# ...
