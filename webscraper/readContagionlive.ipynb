# %%
from bs4 import BeautifulSoup
import requests
import json

url = 'https://www.contagionlive.com/outbreak-monitor-resolved'
#url = 'https://www.contagionlive.com/outbreak-monitor'
response = requests.get(url, timeout=20)
content = BeautifulSoup(response.content,"html.parser")
    
outbreakArr = []

body = content.find('tbody')
instance = body.find('tr', attrs={"class": "outbreakInstance"})
#for instance in content.findAll('tr', attrs={"class": "outbreakInstance"}):
#category = instance.find('td', attrs={"class": "outbreakCategory"})
#disease =  instance.find('td', attrs={"class": "outbreakDisease"})
#name =  instance.find('td', attrs={"class": "outbreakName"})
#location =  instance.find('td', attrs={"class": "outbreakLocation"})
#cases =  instance.find('td', attrs={"class": "outbreakCases"})
#deaths =  instance.find('td', attrs={"class": "outbreakDeaths"})
#source =  instance.find('td', attrs={"class": "outbreakSource"})
#temp = source.find("a", href=True)
#sourceUrl = temp['href']

#outbreak = {
#    "category": category.text,
#    "disease": disease.text,
#    "name": name.text,
#    "location": location.text,
#    "cases": cases.text,
#    "deaths": deaths.text,
#    "sourceUrl": sourceUrl
#}
#outbreakArr.append(outbreak)    

#with open('readHealthMap.json', 'w') as outfile:
#    json.dump(outbreakArr, outfile)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-1-600ab10dce09> in <module>
#       6 #url = 'https://www.contagionlive.com/outbreak-monitor'
#       7 response = requests.get(url, timeout=20)
# ----> 8 content = BeautifulSoup(response.content,"html.parser")
#       9
#      10 outbreakArr = []
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     298          self.contains_replacement_characters) in (
#     299              self.builder.prepare_markup(
# --> 300                  markup, from_encoding, exclude_encodings=exclude_encodings)):
#     301             self.reset()
#     302             try:
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/bs4/builder/_htmlparser.py in prepare_markup(self, markup, user_specified_encoding, document_declared_encoding, exclude_encodings)
#     238         try_encodings = [user_specified_encoding, document_declared_encoding]
#     239         dammit = UnicodeDammit(markup, try_encodings, is_html=True,
# --> 240                                exclude_encodings=exclude_encodings)
#     241         yield (dammit.markup, dammit.original_encoding,
#     242                dammit.declared_html_encoding,
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/bs4/dammit.py in __init__(self, markup, override_encodings, smart_quotes_to, is_html, exclude_encodings)
#     372
#     373         u = None
# --> 374         for encoding in self.detector.encodings:
#     375             markup = self.detector.markup
#     376             u = self._convert_from(encoding)
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/bs4/dammit.py in encodings(self)
#     270         # encoding.
#     271         if self.chardet_encoding is None:
# --> 272             self.chardet_encoding = chardet_dammit(self.markup)
#     273         if self._usable(self.chardet_encoding, tried):
#     274             yield self.chardet_encoding
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/bs4/dammit.py in chardet_dammit(s)
#      31         import chardet
#      32         def chardet_dammit(s):
# ---> 33             return chardet.detect(s)['encoding']
#      34         #import chardet.constants
#      35         #chardet.constants._debug = 1
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/chardet/__init__.py in detect(byte_str)
#      36             byte_str = bytearray(byte_str)
#      37     detector = UniversalDetector()
# ---> 38     detector.feed(byte_str)
#      39     return detector.close()
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/chardet/universaldetector.py in feed(self, byte_str)
#     209                 self._charset_probers.append(Latin1Prober())
#     210             for prober in self._charset_probers:
# --> 211                 if prober.feed(byte_str) == ProbingState.FOUND_IT:
#     212                     self.result = {'encoding': prober.charset_name,
#     213                                    'confidence': prober.get_confidence(),
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/chardet/charsetgroupprober.py in feed(self, byte_str)
#      69             if not prober.active:
#      70                 continue
# ---> 71             state = prober.feed(byte_str)
#      72             if not state:
#      73                 continue
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/chardet/hebrewprober.py in feed(self, byte_str)
#     225             return ProbingState.NOT_ME
#     226
# --> 227         byte_str = self.filter_high_byte_only(byte_str)
#     228
#     229         for cur in byte_str:
#
# ~/anaconda3/envs/insight/lib/python3.7/site-packages/chardet/charsetprober.py in filter_high_byte_only(buf)
#      61     @staticmethod
#      62     def filter_high_byte_only(buf):
# ---> 63         buf = re.sub(b'([\x00-\x7F])+', b' ', buf)
#      64         return buf
#      65
#
# ~/anaconda3/envs/insight/lib/python3.7/re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# MemoryError:

# %%
print(len(outbreakArr))
print(outbreakArr[0])
# Out:
# 287
# {'category': 'Skin & Soft Tissue Diseases', 'disease': 'Acute Flaccid Myelitis', 'name': 'Acute Flaccid Myelitis 2019', 'location': 'Georgia', 'cases': '1', 'deaths': '0', 'sourceUrl': 'https://www.cdc.gov/acute-flaccid-myelitis/cases-in-us.html'}

# %%
import json
with open('readHealthMap.json', 'w') as outfile:
    json.dump(outbreakArr, outfile)
