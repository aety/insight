# %%
from bs4 import BeautifulSoup
import requests

# URL https://paris.demosphere.net/?selectStartTime=1567288801&endTime=1569880801&limit=10000&showArchiveLinks=1
url = 'https://paris.demosphere.net/?selectStartTime=1567288801&endTime=1569880801&limit=10000&showArchiveLinks=1'
response = requests.get(url, timeout=10)
content = BeautifulSoup(response.content,"html.parser")

print(content)
# RESPONSE
# CONTENT
# Out:
# <!DOCTYPE html>
#
# <html lang="fr" xml:lang="fr" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>Démosphère Paris/IdF : agenda alternatif de la région parisienne</title>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noindex, nofollow" name="robots"/>
# <link href="https://paris.demosphere.net/files/images/favicon.cache-11d15.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://paris.demosphere.net/events.xml" rel="alternate" title="Démosphère Paris/IdF RSS" type="application/rss+xml"/>
# <link href="https://paris.demosphere.net/events.ics" rel="alternate" title="Démosphère Paris/IdF iCalendar" type="text/calendar"/>
# <link href="https://paris.demosphere.net" rel="canonical"/>
# <link href="https://mobile.paris.demosphere.net" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link as="image" href="https://paris.demosphere.net/files/images/sprites/frontpage.cache-fec57.png" rel="preload"/>
# <meta content="Manifestations, débats, actions .. un agenda pour aider les habitants de la région parisienne à se rencontrer, à agir, et à se réapproprier la politique." name="description"/>
# <meta content="demosphere,agenda,militant,manifestation,manif,rendez-vous,paris,région parisienne,île de France, 75" name="keywords"/>
# <style type="text/css">
# <!--/*--><![CDATA[/*><!--*/
# .eventmarker.t247{background-color:#ff9000;}.eventmarker.t247>span>i:nth-child(1)::before{border-right:1px solid black;border-top:1px solid black;box-shadow:1px -1px 0 #ff9000,2px -2px 0 #ff9000,3px -3px 0 #ff9000,4px -4px 0 #ff9000,5px -5px 0 #ff9000;}.eventmarker.t247>span>i:nth-child(2)::before{border-left:1px solid black;border-top:1px solid black;box-shadow:-1px -1px 0 #ff9000,-2px -2px 0 #ff9000,-3px -3px 0 #ff9000,-4px -4px 0 #ff9000,-5px -5px 0 #ff9000;}.eventmarker.t248{background-color:#3fc600;}.eventmarker.t248>span>i:nth-child(1)::before{border-right:1px solid black;border-top:1px solid black;box-shadow:1px -1px 0 #3fc600,2px -2px 0 #3fc600,3px -3px 0 #3fc600,4px -4px 0 #3fc600,5px -5px 0 #3fc600;}.eventmarker.t248>span>i:nth-child(2)::before{border-left:1px solid black;border-top:1px solid black;box-shadow:-1px -1px 0 #3fc600,-2px -2px 0 #3fc600,-3px -3px 0 #3fc600,-4px -4px 0 #3fc600,-5px -5px 0 #3fc600;}.eventmarker.t249{background-color:#f00023;}.eventmarker.t249>span>i:nth-child(1)::before{border-right:1px solid black;border-top:1px solid black;box-shadow:1px -1px 0 #f00023,2px -2px 0 #f00023,3px -3px 0 #f00023,4px -4px 0 #f00023,5px -5px 0 #f00023;}.eventmarker.t249>span>i:nth-child(2)::before{border-left:1px solid black;border-top:1px solid black;box-shadow:-1px -1px 0 #f00023,-2px -2px 0 #f00023,-3px -3px 0 #f00023,-4px -4px 0 #f00023,-5px -5px 0 #f00023;}
#
# /*]]>*/-->
# </style>
# <link href="https://paris.demosphere.net/files/css/compressed/95370da8c218a421cbd89756766995a9.css" rel="stylesheet" type="text/css"/>
# </head>
# <body class="role-none not-mobile notFullWidth frontpage">
# <div id="wrap">
# <a class="hprob" href="/flaveolaria"></a> <!--[if IE ]>
# <script type="text/javascript">
# document.body.className+=" IE IE"+navigator.appVersion.match(/MSIE ([0-9]+)/i)[1];
# </script>
# <![endif]--> <div id="main">
# <div id="header">
# <div id="siteName">
# <h1>
# <a href="https://paris.demosphere.net" id="home-link">
# <span id="fp-logo"></span>
# <span id="fp-big-name">démosphère</span>
# </a>
# </h1>
# <h2 id="slogan">agenda alternatif de la région parisienne</h2>
# </div>
# <ul id="secondary-links"><li class="login-link"><a href="https://paris.demosphere.net/login">Connexion</a></li><li id="back-to-mobile"><a href="?switchMobile=mobile">mobile</a></li></ul> <div class="" id="topicSelect"><div class="line line0 lineHasColor"><span class="col" id="sel247"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=247" rel="nofollow">sans-papiers</a></span>
# <span class="col" id="sel248"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=248" rel="nofollow">écologie</a></span>
# <span class="col" id="sel249" title="travail, syndicalisme, classe ouvrière, travailleurs"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=249" rel="nofollow">travail</a></span>
# <span class="col" id="sel250"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=250" rel="nofollow">international</a></span>
# <span class="col" id="sel299" title="enfance, pédagogie, universités, recherche"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=299" rel="nofollow">éducation</a></span>
# <span class="col" id="sel346" title="genre, féminisme, sexisme, LGBT, IVG, sexualité, mariage"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=346" rel="nofollow">sexisme</a></span>
# </div><div class="line line1 lineNoColor"><span class="nocol" id="sel347" title="prisons, police, violence policière, système judiciaire, répression anti-syndicale, enfermement, psychiatrie"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=347" rel="nofollow">répression</a></span>
# <span class="nocol" id="sel348"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=348" rel="nofollow">économie</a></span>
# <span class="nocol" id="selothers" title="Rendez-vous n'ayant aucun des autres thèmes"><a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1&amp;highlightTopic=others" rel="nofollow"></a></span>
# </div></div> <div id="searchButton">
# <form action="https://paris.demosphere.net/search" method="get">
# <input id="search-field" name="search" placeholder="Recherche" type="search"/><button id="search-submit" type="submit"> </button>
# </form>
# </div>
# <div id="options-wrap">
# <div id="options">
# <div class="form-item form-item-select options-button" id="edit-select-topic-wrapper" title="Thème"><select class="" id="edit-select-topic" name="select-topic">
# </select></div><div class="form-item form-item-select options-button" id="edit-most-visited-wrapper" title="Rdv les plus vus"><select class="" id="edit-most-visited" name="most-visited">
# <option selected="selected" value="0">--</option><option value="5">5</option><option value="10">10</option><option value="15">15</option><option value="20">20</option><option value="25">25</option><option value="30">30</option><option value="35">35</option><option value="45">45</option><option value="60">60</option><option value="80">80</option><option value="100">100</option><option value="130">130</option><option value="160">160</option>
# </select></div><div class="form-item form-item-select options-button" id="edit-max-nb-events-per-day-wrapper" title="Nombre max de rdv par jour"><select class="" id="edit-max-nb-events-per-day" name="max-nb-events-per-day">
# <option selected="selected" value="0">--</option><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="16">16</option><option value="17">17</option><option value="18">18</option><option value="19">19</option>
# </select></div><div class="form-item form-item-select options-button" id="edit-select-recent-changes-wrapper" title="Nouveaux rendez-vous depuis"><select class="" id="edit-select-recent-changes" name="select-recent-changes">
# <option selected="selected" value="0">--</option><option value="21600">il y a 6 heures</option><option value="86400">il y a 1 jour</option><option value="172800">il y a 2 jours</option><option value="259200">il y a 3 jours</option><option value="345600">il y a 4 jours</option><option value="432000">il y a 5 jours</option><option value="604800">il y a 7 jours</option><option value="1296000">il y a 15 jours</option><option value="2592000">il y a 30 jours</option>
# </select></div><div class="form-item form-item-checkbox options-button" id="edit-order-by-last-big-changes-wrapper" title="Changement récents en premier"><input class="" id="edit-order-by-last-big-changes" name="order-by-last-big-changes" type="checkbox"/></div><div id="near-lat-lng-pwrap"><span class="options-button" id="near-lat-lng-button" title="Choisir les RdV proches d'un endroit, en positionnant cet endroit sur une carte"></span><div class="options-popup" id="near-lat-lng-popup">...</div></div><div id="more-options"><span id="more-options-button">+</span><div class="options-popup" id="more-options-popup">...</div></div> </div>
# <div id="options-extra">
# <a id="options-link"></a>
# <a href="https://paris.demosphere.net" id="options-clear">x</a></div>
# </div>
# </div>
# <a class="hprob" href="/hprobzarc"></a> <div id="calendar">
# <div id="archive"><h4>Affichage des rendez-vous archivés: <strong>septembre 2019</strong> <span>(<a href="/?limit=10000">retour à l'agenda d'aujourd'hui</a>)</span></h4><table><tr><th>2007</th><td></td><td></td><td><a href="/?selectStartTime=1172703601&amp;endTime=1175378401&amp;limit=10000&amp;showArchiveLinks=1">mars</a></td><td><a href="/?selectStartTime=1175378401&amp;endTime=1177970401&amp;limit=10000&amp;showArchiveLinks=1">avril</a></td><td><a href="/?selectStartTime=1177970401&amp;endTime=1180648801&amp;limit=10000&amp;showArchiveLinks=1">mai</a></td><td><a href="/?selectStartTime=1180648801&amp;endTime=1183240801&amp;limit=10000&amp;showArchiveLinks=1">juin</a></td><td><a href="/?selectStartTime=1183240801&amp;endTime=1185919201&amp;limit=10000&amp;showArchiveLinks=1">juillet</a></td><td><
# <tr><td><a href="?a=1571007600#d14-10">14</a></td><td><a href="?a=1571094000#d15-10">15</a></td><td><a href="?a=1571180400#d16-10">16</a></td><td><a href="?a=1571266800#d17-10">17</a></td><td><a href="?a=1571353200#d18-10">18</a></td><td class="w6"><a href="?a=1571439600#d19-10">19</a></td><td class="w7"><a href="?a=1571526000#d20-10">20</a></td></tr>
# <tr><td><a href="?a=1571612400#d21-10">21</a></td><td><a href="?a=1571698800#d22-10">22</a></td><td><a href="?a=1571785200#d23-10">23</a></td><td><a href="?a=1571871600#d24-10">24</a></td><td><a href="?a=1571958000#d25-10">25</a></td><td class="w6"><a href="?a=1572044400#d26-10">26</a></td><td class="w7"><a href="?a=1572130800#d27-10">27</a></td></tr>
# <tr><td><a href="?a=1572220800#d28-10">28</a></td><td><a href="?a=1572307200#d29-10">29</a></td><td><a href="?a=1572393600#d30-10">30</a></td><td><a href="?a=1572480000#d31-10">31</a></td><td class="x"><a href="?a=1572566400#d1-11">1</a></td><td class="w6 x"><a href="?a=1572652800#d2-11">2</a></td><td class="w7 x"><a href="?a=1572739200#d3-11">3</a></td></tr>
# <tr><td class="x"><a href="?a=1572825600#d4-11">4</a></td><td class="x"><a href="?a=1572912000#d5-11">5</a></td><td class="x"><a href="?a=1572998400#d6-11">6</a></td><td class="x"><a href="?a=1573084800#d7-11">7</a></td><td class="x"><a href="?a=1573171200#d8-11">8</a></td><td class="w6 x"><a href="?a=1573257600#d9-11">9</a></td><td class="w7 x"><a href="?a=1573344000#d10-11">10</a></td></tr>
# </table></div><p id="archives-link"><a href="?limit=1000#m11">novembre</a>, <a href="?limit=1000#m12">décembre</a>, <a href="/?selectStartTime=1567288801&amp;endTime=1569880801&amp;limit=10000&amp;showArchiveLinks=1" id="archive-link" rel="nofollow">archives</a></p></div></div> <div class="demosphereMapLink stdInfobox whiteInfobox" id="infobox46"><h3 class="infobox-title"><a href="https://paris.demosphere.net/map"><span>Frontpage map link</span></a></h3><div class="ibContent"><p class="eventmarker t247">20:30<span><i></i><i></i></span></p>
# <p class="eventmarker t248">18:30<span><i></i><i></i></span></p>
# <p class="eventmarker t249">19:30<span><i></i><i></i></span></p>
# </div></div><div class="infoboxLogo" id="infoboxLogo30"></div><div class="infoboxWithLogo stdInfobox" id="infobox30"><h3 class="infobox-title"><span>Participez !</span></h3><div class="ibContent"><h2 id="publicFormButton">
# <a href="/publish">Publiez un RV</a>
# </h2>
# <h2>
# <a href="/contact">Contactez-nous</a>
# </h2>
# <h2>
# <a href="/faites-connaitre">Faites connaître</a>
# </h2>
# <h2>
# <a href="https://demosphere.net/fr/content/soutien-financier">Faîtes un don</a>
# </h2></div></div><div class="infoboxStayInformed fullInfobox" id="infobox47"><h3 class="infobox-title"><span>Restez informés !</span></h3><div class="ibContent"><p id="rss-logo">rss-logo</p><ul>
# <li>
# <a href="/aide-rdv-par-courrier">par e-mail</a> <span class="email"></span>
# </li>
# <li>
# <a href="/aide-flux-rss">flux RSS</a>
# </li>
# <li>
# <a href="/aide-ical">iCal</a>
# </li>
# <li>
# <a href="/aide-sur-votre-site-web">sur votre site web</a>
# </li>
# </ul></div></div><div class="stdInfobox" id="infobox29"><h3 class="infobox-title"><a href="https://paris.demosphere.net/qui-sommes-nous"><span>démosphère ?</span></a></h3><div class="ibContent"><p>
#   Démosphère est un agenda web indépendant de toute organisation ou parti.
# </p>
# <p>
#   Nous parcourons, tous les jours, des <a href="/sources-des-rendez-vous">centaines de mails et de pages web</a> pour trouver, saisir et présenter ces rendez-vous.
# </p>
# <p>
#   Régions: <a href="https://alter49.org">Alter49</a>, <a href="https://ariege.demosphere.net">Ariège</a>, <a href="https://bxl.demosphere.net">Brussels</a>, <a href="https://carcassonne.demosphere.net">Carcassonne</a>, <a href="https://gard.demosphere.net">Gard</a>, <a href="https://gironde.demosphere.net">Gironde</a>, <a href="https://lille.demosphere.net">Lille</a>, <a href="https://herault.demosphere.net">Hérault</a>, <a href="https://nice.demosphere.net">Nice</a>, <a href="https://paris.demosphere.net">Paris</a>, <a href="https://rennes.demosphere.net">Rennes</a>, <a href="https://rouen.demosphere.net">Rouen</a>, <a href="https://tarn.demosphere.net">Tarn</a>, <a href="https://toulouse.demosphere.net">Toulouse</a>, <a href="https://liege.demosphere.net">Liège</a>, <a href="https://poitiers.demosphere.net">Poitiers</a>, <a href="https://strasbourgfurieuse.demosphere.net">Strasbourg</a>, <a href="https://05.demosphere.net">Hautes Alpes</a>, <a href="https://somme.demosphere.net">Somme</a>, <a href="https://lot.demosphere.net">Lot</a>, <a href="https://maraispoitevin.demosphere.net">Marais poitevin</a>, <a href="https://sarthe.demosphere.net">Sarthe</a>, <a href="https://dunkerque.demosphere.net">Dunkerque</a>, <a href="https://comminges.demosphere.net">Comminges</a>, <a href="https://limoges.demosphere.net">Limoges</a>, <a href="https://63.demosphere.net">Puy de Dôme</a>, <a href="https://namur.demosphere.net">Namur</a>, <a href="https://aveyron.demosphere.net">Aveyron</a>, <a href="https://roannais.demosphere.net">Roannais</a>.
# </p>
# <h4>
#   Plus d'infos : <a href="/qui-sommes-nous">qui sommes nous</a> ?
# </h4>
# <h2 id="manifestations-paris-fp-link">
# <a href="/manifestations-paris">Manifestations à Paris</a>
# </h2></div></div> </div>
# <div id="footer">
# <div id="extra-back-to-mobile"><a href="https://paris.demosphere.net/?switchMobile=mobile">mobile</a>
# </div>
# </div>
# </div><!-- end wrap -->
# <script type="text/javascript">var base_url="https:\/\/paris.demosphere.net";
# var demosphere_config={"map_center_latitude":48.856696,"map_center_longitude":2.350817,"map_zoom":11,"frontpage_regions_url_name":"xyzcity","locale":"fr_FR.utf8","mapbox_access_token":"pk.eyJ1IjoiZGVtb3NwaGVyZSIsImEiOiJjamtoNzl6aDkwcm96M3BreGZreDVlNG01In0.1Wqt0NzH4tmUICE1Whcgrw"};
# </script>
# <script type="text/javascript">window.onerror=function(msg,url,line,col,error){if(typeof demosphere_errct==="undefined"){demosphere_errct=0;}if(demosphere_errct++>=4){return;}document.createElement("img").src="/js-error-report?msg="+encodeURIComponent(msg)+"&url="+encodeURIComponent(url)+"&line="+line+"&col="+col+"&error="+encodeURIComponent(error)+(typeof error==="object" && error!==null &&  typeof error.stack!=="undefined" ? "&stack="+encodeURIComponent(error.stack) : "");};</script>
# <script type="text/javascript">
# function add_script(u,as,cb){var s=document.createElement("script");s.type="text/javascript";if(u.indexOf("http")!==0  && u.indexOf("//")!==0){u=base_url+(u.indexOf("/")!==0 ? "/" : "")+u}s.async=as ? "async" : false;s.src=u;var finish=false;if(as){finish=cb}else{var so={is_loading:true, url:u, wfs_callbacks:[]};add_script.scripts.push(so);if(typeof $!=="undefined")$.holdReady(true);finish=function(){so.is_loading=false;if(cb)cb();while(so.wfs_callbacks.length)so.wfs_callbacks.shift()();wait_document_ready();if(typeof $!=="undefined")$.holdReady(false)}}if(finish){if(s.readyState){s.onreadystatechange=function(){if(s.readyState=="loaded" || s.readyState=="complete"){s.onreadystatechange=null;finish()}}}else{s.onload=function(){finish()}}}document.getElementsByTagName('head')[0].appendChild(s)}add_script.scripts=[];function wait_for_script(cb){var last=add_script.scripts[add_script.scripts.length-1];if(!last || !last.is_loading)cb();else  last.wfs_callbacks.push(cb)}function wait_document_ready(f){var self=wait_document_ready;if(typeof f==='function')self.callbacks.push(f);if(!('document_is_ready' in self)){self.document_is_ready=document.readyState!=='loading';document.addEventListener('DOMContentLoaded', function(){self.document_is_ready=true;self()},false)}if(!self.document_is_ready)return;for(var i=0;i<add_script.scripts.length;i++){if(add_script.scripts[i].is_loading)return}while(self.callbacks.length)self.callbacks.shift()()}wait_document_ready.callbacks=[]
# </script>
# <script type="text/javascript">var demosphere_frontpage={"jquery_js_path":"lib\/jquery.cache-91ee9.js","demosphere_frontpage_options_js_path":"demosphere\/js\/demosphere-frontpage-options.cache-91ee9.js","demosphere_event_list_form_js_path":"demosphere\/js\/demosphere-event-list-form.cache-91ee9.js","topics":{"247":"sans-papiers","248":"\u00e9cologie","249":"travail","250":"international","299":"\u00e9ducation","346":"sexisme","347":"r\u00e9pression","348":"\u00e9conomie"}};</script>
# <script>
# var supportsAsync=true;try{new Function("async function a(){}")()}catch(e){supportsAsync=false}var isOldBrowser=!supportsAsync;if(isOldBrowser){add_script("/lib/old-browsers.js",false)}</script>
# <script>
# function js_compat(path){if(!isOldBrowser || /t[34]\.php$/.test(path)){add_script("/"+path,false)}else{add_script("/js-compat/"+path,false)}}</script>
# <script>js_compat("demosphere/js/demosphere-frontpage.cache-91ee9.js")</script>
# <script type="text/javascript">translations={"dr1":"rdv le plus visit\u00e9 pour cette journ\u00e9e","dr2":"deuxi\u00e8me rdv le plus visit\u00e9 pour cette journ\u00e9e"};
# function t(s,placeholders)
# {
#     var str=translations[s];
#     if(typeof str==="undefined"){alert("missing translation:"+s);}
#     if(typeof placeholders==="undefined"){return str;}
#     for(var ph in placeholders)
#     {
#         if(!placeholders.hasOwnProperty(ph)){continue;}
#         str=str.replace(prop,placeholders[prop]);
#     }
#     return str;
# }</script>
# </body>
# </html>
