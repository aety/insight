# %%
from bs4 import BeautifulSoup
import requests
import json

url = 'https://www.healthmap.org/en/'
response = requests.get(url, timeout=10)
content = BeautifulSoup(response.content,"html.parser")

test = content.find('div', attrs={"id": "list_view_table_wrapper"})
print(test)
# Out:
# None
