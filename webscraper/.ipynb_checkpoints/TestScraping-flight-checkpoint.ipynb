# %%
from bs4 import BeautifulSoup
import requests

yearArr = list(range(2015,2020)) # years to parse through

diseaseArr = [] # preallocate

for year in yearArr:
    
    print(year)
    
    # URL 
    # RESPONSE
    # CONTENT
    url = 'https://www.who.int/csr/don/archive/year/' + str(year) + '/en/'
    response = requests.get(url, timeout=10)
    content = BeautifulSoup(response.content,"html.parser")
    
    li = content.find('ul', attrs={"class": "auto_archive"})
    for disease_date in li.findAll('li'):
        date = disease_date.find("a", href=True)
        nameStr = disease_date.find('span', attrs={"class": "link_info"})
        temp = nameStr.text#.encode('utf-8')        
        temp = temp.replace(', ',' – ') # replace commas with full dashes
        temp = temp.replace(' - ',' – ') # replace semi dashes with full dashes
        temp = temp.replace(' in ',' – ') # replace "in" with full dashes
        nameSplit = temp.split("–") # split at the dashes
        
        disease = {
            "diseaseName": nameSplit[0],
            "countryName": nameSplit[1],
            "date": date.text,
            "link": date['href']
        }
        diseaseArr.append(disease)
    
with open('whoDiseaseOutbreaks.json', 'w') as outfile:
    json.dump(diseaseArr, outfile)
# Out:
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
import json 
with open('whoDiseaseOutbreaks.json') as json_data:
    jsonData = json.load(json_data)

    for i in jsonData:        
        if "2017" in i['date']: # only print entries with a certain keywords
            print(i['date'])     # only print entries with a certain keywords
# Out:
# 22 December 2017
# 22 December 2017
# 22 December 2017
# 22 December 2017
# 21 December 2017
# 19 December 2017
# 13 December 2017
# 11 December 2017
# 11 December 2017
# 27 November 2017
# 24 November 2017
# 15 November 2017
# 15 November 2017
# 10 November 2017
# 7 November 2017
# 7 November 2017
# 6 November 2017
# 2 November 2017
# 26 October 2017
# 26 October 2017
# 25 October 2017
# 15 October 2017
# 9 October 2017
# 2 October 2017
# 29 September 2017
# 29 September 2017
# 21 September 2017
# 15 September 2017
# 13 September 2017
# 12 September 2017
# 6 September 2017
# 5 September 2017
# 30 August 2017
# 28 August 2017
# 25 August 2017
# 17 August 2017
# 7 August 2017
# 4 August 2017
# 21 July 2017
# 19 July 2017
# 19 July 2017
# 12 July 2017
# 12 July 2017
# 6 July 2017
# 6 July 2017
# 4 July 2017
# 28 June 2017
# 28 June 2017
# 28 June 2017
# 19 June 2017
# 13 June 2017
# 13 June 2017
# 13 June 2017
# 8 June 2017
# 7 June 2017
# 6 June 2017
# 26 May 2017
# 23 May 2017
# 18 May 2017
# 13 May 2017
# 9 May 2017
# 5 May 2017
# 5 May 2017
# 1 May 2017
# 27 April 2017
# 24 April 2017
# 20 April 2017
# 18 April 2017
# 5 April 2017
# 4 April 2017
# 4 April 2017
# 3 April 2017
# 3 April 2017
# 28 March 2017
# 24 March 2017
# 23 March 2017
# 20 March 2017
# 16 March 2017
# 15 March 2017
# 10 March 2017
# 10 March 2017
# 6 March 2017
# 27 February 2017
# 24 February 2017
# 23 February 2017
# 22 February 2017
# 20 February 2017
# 20 February 2017
# 10 February 2017
# 27 January 2017
# 26 January 2017
# 24 January 2017
# 18 January 2017
# 17 January 2017
# 17 January 2017
# 13 January 2017
# 9 January 2017
# 3 January 2017
