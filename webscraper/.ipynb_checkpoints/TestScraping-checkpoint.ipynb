# %%
from bs4 import BeautifulSoup
import requests

# URL 
url = 'http://ethans_fake_twitter_site.surge.sh/'
#url = 'https://www.who.int/csr/don/archive/year/2018/en/'
response = requests.get(url, timeout=10)
content = BeautifulSoup(response.content,"html.parser")

####
# Main test: span class "link_info"
# Date (with url): a href


#print(response) # should be a number such as 200
#print(content)

tweet = content.find('p', attrs={"class": "content"}).text
#tweet = content.find('span',attrs={"class": "link_info"}).text
print(tweet)
# RESPONSE
# CONTENT
# Out:
# Tonight: @MichaelKeaton, @ninadobrev, music from @The_xx, and more! #FallonTonight
